# %%
with open("test.txt","w") as file:
    file.write("successfully install")

# %%
import pandas as pd

# %%
states=['cali','flor','tex','ny']
population=[6,5,4,7]
dict_states={'States':states,'Population':population}
df=pd.DataFrame.from_dict(dict_states)

# %%
df.to_csv('states.csv',index=False)

# %%
new_list=[2,'b',6,'cali']
for i in new_list:
    try:
        print(i/2)
    except:
        print('not a number')
# Out:
# 1.0
# not a number
# 3.0
# not a number

# %%
n=4
while n>0:
    print(n)
    n-=1
    if n==2:
        break
print('end loop')
# Out:
# 4
# 3
# end loop

# %% [markdown]
# create driver

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# %%
website='https://www.adamchoi.co.uk/overs/detailed'
path=Service("C:\\Users\\Sicario\\Downloads\\chromedriver-win64\\chromedriver-win64\\chromedriver.exe")
driver=webdriver.Chrome(service=path)
driver.get(website)

# %%
all_matches=driver.find_element(By.XPATH,'//label[@analytics-event="All matches"]')
all_matches.click()

# %%
#driver.quit()

# %%
matches=driver.find_elements(By.TAG_NAME,'tr')
#for match in matches:
 #   print(match.text)

 date=[]
 home_team=[]
 score=[]
 away_team=[]

for match in matches:
    date.append(match.find_element(By.XPATH,'//td/tr[1]').text)
    home_team.append(match.find_element(By.XPATH,'//td/tr[2]').text)
    score.append(match.find_element(By.XPATH,'//td/tr[3]').text)
    away_team.append(match.find_element(By.XPATH,'//td/tr[4]').text)
# Out:
# 12-08-2023 Arsenal 2 - 1 Nott'm Forest
# 21-08-2023 Crystal Palace 0 - 1 Arsenal
# 26-08-2023 Arsenal 2 - 2 Fulham
# 03-09-2023 Arsenal 3 - 1 Man United
# 17-09-2023 Everton 0 - 1 Arsenal
# 24-09-2023 Arsenal 2 - 2 Tottenham
# 30-09-2023 Bournemouth 0 - 4 Arsenal
# 08-10-2023 Arsenal 1 - 0 Man City
# 21-10-2023 Chelsea 2 - 2 Arsenal
# 28-10-2023 Arsenal 5 - 0 Sheffield United
# 04-11-2023 Newcastle 1 - 0 Arsenal
# 11-11-2023 Arsenal 3 - 1 Burnley
# 25-11-2023 Brentford 0 - 1 Arsenal
# 02-12-2023 Arsenal 2 - 1 Wolves
# 05-12-2023 Luton 3 - 4 Arsenal
# 09-12-2023 Aston Villa 1 - 0 Arsenal
# 17-12-2023 Arsenal 2 - 0 Brighton
# 23-12-2023 Liverpool 1 - 1 Arsenal
# 28-12-2023 Arsenal 0 - 2 West Ham
# 31-12-2023 Fulham 2 - 1 Arsenal
# 20-01-2024 Arsenal 5 - 0 Crystal Palace
# 30-01-2024 Nott'm Forest 1 - 2 Arsenal
# 04-02-2024 Arsenal 3 - 1 Liverpool
# 11-02-2024 West Ham 0 - 6 Arsenal
# 17-02-2024 Burnley 0 - 5 Arsenal
# 24-02-2024 Arsenal 4 - 1 Newcastle
# ...
